# %%
import pandas as pd
import json
import functools
import re
import spacy
from spacy.tokens import Doc
import itertools as it
from nltk.tokenize import TweetTokenizer
from spacy.lang.en import STOP_WORDS
from gensim.models import Phrases
from gensim.models.word2vec import LineSentence
from gensim.corpora import Dictionary, MmCorpus
from gensim.models import LdaModel

import pyLDAvis
import pyLDAvis.gensim
import pickle
import codecs
from spacy.pipeline import Pipe
# Out:
# E:\anaconda\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
'''
source: https://stackoverflow.com/questions/21708192/how-do-i-use-the-json-module-to-read-in-one-json-object-at-a-time/21709058
provided by: unutbu
'''
def json_parse(fileobj, decoder=json.JSONDecoder(), buffersize=2048, 
               delimiters=None):
    remainder = ''
    for chunk in iter(functools.partial(fileobj.read, buffersize), ''):
        remainder += chunk
        while remainder:
            try:
                stripped = remainder.strip(delimiters)
                result, index = decoder.raw_decode(stripped)
                yield result
                remainder = stripped[index:]
            except ValueError:
                # Not enough data to decode, read more
                break

# %%
with open('../data/tweets.txt', 'r') as rf:
    json_list = list(json_parse(rf))

# %%
len(json_list)
# Out:
# 2000

# %%
for i in range(30, 35):
    json = json_list[i]
    try:
        text = json["retweeted_status"]["extended_tweet"]["full_text"]
    except KeyError:
        text = json["text"]
    print(text)
    print()
# Out:
# 12652.916 USD  https://t.co/3T5IP5YsEn | #btc #bitcoin #blockchain #cryptocurrency https://t.co/eB0Ji7u78N
#
# Something to consider if you suffer from #fomo over bitcoin: you might make or lose money by investing now, but you won’t lose anything by NOT investing.
#
# Few great quotes in this article: https://t.co/S910SsTFDX
#
# 12660.50 USD  https://t.co/vmknxeCRiL | #btc #bitcoin #blockchain #cryptocurrency https://t.co/a186DDXLAU
#
# Lightning Network May Not Solve Bitcoin's Scaling 'Trilemma' https://t.co/umtLQyur31 #bitcoin #blockchain Via… https://t.co/tCpYmvbDJL
#
# MAKE MONEY WITH bitcoin!!!
#
# ✅KUCOIN is 100% OPEN!!!
#
# CLICK ▶️ https://t.co/lPgWGdMR6i
#
# ❌Binance
# ❌Poloniex
# ❌Bittre… https://t.co/YjUgq2T3mC

# %%
nlp = spacy.load('en')
# Out:
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# E:\anaconda\lib\site-packages\msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# E:\anaconda\lib\site-packages\msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])

# %%
ttkzr = TweetTokenizer(strip_handles=True, reduce_len=True)

# %%
docs = []
for json in json_list:
    try:
        text = json["retweeted_status"]["extended_tweet"]["full_text"]
    except KeyError:
        text = json["text"]
    text_nourl = re.sub(r"http\S+", "", text)
    tokens = ttkzr.tokenize(text_nourl)
    doc = Doc(nlp.vocab, words=tokens)
    docs.append(doc)

# %%
docs[90]
# Out:
# JOIN THE LARGEST #BITCOIN #CRYPTO NETWORK ON EARTH ! EMAIL : cryptopennystock@gmail.com #CryptoCurrencyGod #TEAMBILLIONAIRE #PENNYSTOCKS #STOCKALERT #BTC , #ETH , #ADA #XRP #TRX #LTC #BLOCKCHAIN

# %%
docs_filepath = '../data/docs.txt'

# %%
with open(docs_filepath, 'w', encoding='utf_8') as wf:
    for doc in docs:
        wf.write(doc.text)
        wf.write("\n")

# %%
'''
source: Modern NLP in Python
author: Patrick Harrison
'''
def punct_space(token):
    """
    helper function to eliminate tokens
    that are pure punctuation or whitespace
    """
    
    return token.is_punct or token.is_space

def line_review(filename):
    """
    generator function to read in reviews from the file
    and un-escape the original line breaks in the text
    """
    
    with open(filename, encoding='utf_8') as f:
        for review in f:
            yield review.replace('\\n', '\n')
            
def lemmatized_sentence_corpus(filename):
    """
    generator function to use spaCy to parse reviews,
    lemmatize the text, and yield sentences
    """
    
    for parsed_review in nlp.pipe(line_review(filename),
                                  batch_size=10000, n_threads=4):
        
        for sent in parsed_review.sents:
            yield u' '.join([token.lemma_ for token in sent
                             if not punct_space(token)])

# %%
unigram_sentences_filepath = '../data/unigram_sentences.txt'

# %%
with open(unigram_sentences_filepath, 'w', encoding='utf-8') as f:
    for sentence in lemmatized_sentence_corpus(docs_filepath):
        f.write(sentence + '\n')

# %%
unigram_sentences = LineSentence(unigram_sentences_filepath)

# %%
for sentence in it.islice(unigram_sentences, 230, 240):
    print(sentence)
# Out:
# ['join', '-PRON-', 'ico', 'now']
# ['here', 'be', 'a', 'link', 'and', '-PRON-', 'know', 'what', 'to', 'do', 'next', '😉']
# ['become', 'a', 'part', 'of', 'first', 'ecocryptomin', 'in', 'the', 'world']
# ['invest', 'investment', 'innovate', 'innovation', 'mining', 'miningfarm', 'crypto', 'profit', 'bitcoin', 'ethereum', 'cryptocurrency']
# ['st']
# ['james', 'place', 'condos', 'in', 'columbia', 'heights', 'accept', 'bitcoin', 'as', 'payment', 'washington', 'business', 'journal']
# ['rt']
# ['-PRON-', 'wish', 'man', 'would', 'put', 'as', 'much', 'confidence', 'in', 'woman', 'as', '-PRON-', 'do', 'in', 'bitcoin']
# ['there', 'be', 'a', 'direct', 'correlation', 'between', 'the', 'growth', 'in', 'the', 'number', 'of', 'successful', 'and', 'reliable', 'project', 'and', 'the', 'arrival', 'of', 'new', 'investor', 'on', 'the', 'market', 'whose', 'interest', 'will', 'increase', 'significantly']
# ['rr', 'revizorcoin', 'cryptocurrency', 'ico', 'blockchain']

# %%
crypto_names = pd.read_csv('../data/crypto-markets.csv')

# %%
crypto_names = crypto_names[['slug', 'symbol']]
crypto_names.drop_duplicates(inplace=True)

# %%
crypto_names['symbol'] = crypto_names['symbol'].str.lower()
crypto_names['slug'] = crypto_names['slug'].str.replace('-', '_')
crypto_names.head()
# Out:
#               slug symbol
# 0          bitcoin    btc
# 1719      ethereum    eth
# 2607        ripple    xrp
# 4228  bitcoin_cash    bch
# 4400       cardano    ada

# %%
crypto_dict = dict(zip(crypto_names['symbol'].values, crypto_names['slug'].values))

# %%
crypto_dict
# Out:
# {'btc': 'bitcoin',
#  'eth': 'ethereum',
#  'xrp': 'ripple',
#  'bch': 'bitcoin_cash',
#  'ada': 'cardano',
#  'ltc': 'litecoin',
#  'xem': 'nem',
#  'miota': 'iota',
#  'xlm': 'stellar',
#  'dash': 'dash',
#  'neo': 'neo',
#  'trx': 'tron',
#  'eos': 'eos',
#  'xmr': 'monero',
#  'icx': 'icon',
#  'btg': 'bitgem',
#  'xrb': 'raiblocks',
#  'qtum': 'qtum',
#  'etc': 'ethereum_classic',
#  'lsk': 'lisk',
#  'omg': 'omisego',
#  'xvg': 'verge',
#  'sc': 'siacoin',
#  'zec': 'zcash',
#  'bnb': 'binance_coin',
#  'bcn': 'bytecoin_bcn',
#  'ppt': 'populous',
#  'bcc': 'bitconnect',
#  'ven': 'vechain',
#  'strat': 'stratis',
#  'kcs': 'kucoin_shares',
#  'bts': 'bitshares',
#  'usdt': 'tether',
#  'ardr': 'ardor',
#  'snt': 'status',
#  'doge': 'dogecoin',
#  'waves': 'waves',
#  'steem': 'steem',
#  'drgn': 'dragonchain',
#  'dcn': 'dentacoin',
#  'zrx': '0x',
#  'dgb': 'digibyte',
#  'rep': 'augur',
#  'wax': 'wax',
#  'veri': 'veritaseum',
#  'ark': 'ark',
#  'dent': 'dent',
#  'etn': 'electroneum',
#  'kmd': 'komodo',
#  'hsr': 'hshare',
#  'gnt': 'golem_network_tokens',
#  'bat': 'batcoin',
#  'pivx': 'pivx',
#  'dcr': 'decred',
#  'salt': 'salt',
#  'ethos': 'ethos',
#  'xp': 'experience_points',
#  'knc': 'kingn_coin',
#  'qash': 'qash',
#  'fun': 'funfair',
#  'kin': 'kin',
#  'rdd': 'reddcoin',
#  'fct': 'factom',
#  'eng': 'enigma_project',
#  'med': 'medibloc',
#  'btm': 'bitmark',
#  'aion': 'aion',
#  'nxs': 'nexus',
#  'ae': 'aeternity',
#  'req': 'request_network',
#  'elf': 'aelf',
#  'sub': 'substratum',
#  'gas': 'gas',
#  'powr': 'power_ledger',
#  'zcl': 'zclassic',
#  'rhoc': 'rchain',
#  'xdn': 'digitalnote',
#  'gbyte': 'byteball',
#  'mona': 'monacoin',
#  'nebl': 'neblio',
#  'maid': 'maidsafecoin',
#  'sys': 'syscoin',
#  'nxt': 'nxt',
#  'link': 'chainlink',
#  'btcd': 'bitcoindark',
#  'dgd': 'digixdao',
#  'cob': 'cobinhood',
#  'san': 'santiment',
#  'icn': 'icoin',
#  'gno': 'gnosis_gno',
#  'wtc': 'walton',
#  'bnt': 'bancor',
#  'xzc': 'zcoin',
#  'gxs': 'gxshares',
#  'dbc': 'deepbrain_chain',
#  'poe': 'poet',
#  'qsp': 'quantstamp',
#  'vee': 'blockv',
#  'game': 'gamecredits',
#  'storm': 'storm',
#  'smart': 'smartbillions',
#  'rdn': 'raiden_network_token',
#  'pay': 'tenx',
#  'act': 'achain',
#  'utk': 'utrust',
#  'cvc': 'civic',
#  'sky': 'skycoin',
#  'vibe': 'vibe',
#  'tnb': 'time_new_bank',
#  'pac': 'paccoin',
#  'xpa': 'xplay',
#  'rpx': 'red_pulse',
#  'lend': 'ethlend',
#  'storj': 'storj',
#  'vtc': 'vertcoin',
#  'ast': 'airswap',
#  'xby': 'xtrabytes',
#  'emc': 'emercoin',
#  'enj': 'enjin_coin',
#  'ppp': 'paypie',
#  'plr': 'pillar',
#  'xcp': 'counterparty',
#  'nav': 'nav_coin',
#  'block': 'blocknet',
#  'cnx': 'cryptonex',
#  'ost': 'simple_token',
#  'wabi': 'wabi',
#  'r': 'revain',
#  'bay': 'bitbay',
#  'bco': 'bridgecoin',
#  'srn': 'sirin_labs_token',
#  'mco': 'monaco',
#  'dtr': 'dynamic_trading_rights',
#  'ant': 'aragon',
#  'part': 'particl',
#  'rcn': 'rcoin',
#  'ctr': 'centra',
#  'ubq': 'ubiq',
#  'cmt': 'comet',
#  'mana': 'decentraland',
#  'fuel': 'etherparty',
#  'rlc': 'rlc',
#  'atm': 'attention_token_of_media',
#  'snm': 'sonm',
#  'cnd': 'cindicator',
#  'itc': 'iot_chain',
#  'edg': 'edgeless',
#  'sngls': 'singulardtv',
#  'mod': 'modum',
#  'data': 'streamr_datacoin',
#  'nuls': 'nuls',
#  'wgr': 'wagerr',
#  'zen': 'zencash',
#  'ukg': 'unikoin_gold',
#  'spank': 'spankchain',
#  'adx': 'adx_net',
#  'brd': 'bread',
#  'qrl': 'quantum_resistant_ledger',
#  'ppc': 'peercoin',
#  'thc': 'hempcoin',
#  'amb': 'amber',
#  'wings': 'wings',
#  'dnt': 'district0x',
#  'dlt': 'agrello_delta',
#  'mgo': 'mobilego',
#  'emc2': 'einsteinium',
#  'etp': 'metaverse',
#  'xas': 'asch',
#  'burst': 'burst',
#  'via': 'viacoin',
#  'lbc': 'library_credit',
#  'trig': 'triggers',
#  '1st': 'firstblood',
#  'mln': 'melon',
#  'nlg': 'gulden',
#  'dct': 'decent',
#  'moon': 'mooncoin',
#  'mth': 'monetha',
#  'lun': 'lunyr',
#  'agrs': 'agoras_tokens',
#  'snov': 'snovio',
#  'edo': 'eidoo',
#  'tnt': 'tierion',
#  'rise': 'rise',
#  'shift': 'shift',
#  'xsh': 'shield_xsh',
#  'hst': 'decision_token',
#  'flash': 'flash',
#  'la': 'latoken',
#  'aeon': 'aeon',
#  'cloak': 'cloakcoin',
#  'grid': 'grid',
#  'mtl': 'metal',
#  'gto': 'gifto',
#  'trst': 'trust',
#  'ixt': 'ixledger',
#  'lrc': 'loopring',
#  'gvt': 'genesis_vision',
#  'cdt': 'coindash',
#  'prl': 'oyster_pearl',
#  'pre': 'presearch',
#  'tkn': 'tokencard',
#  'pura': 'pura',
#  'ink': 'ink',
#  'vox': 'voxels',
#  'coss': 'coss',
#  'dpy': 'delphy',
#  'adt': 'adtoken',
#  'vib': 'viberate',
#  'ioc': 'iocoin',
#  'sls': 'salus',
#  'xspec': 'spectrecoin',
#  'ftc': 'feathercoin',
#  'cfi': 'cofound_it',
#  'taas': 'taas',
#  'grs': 'groestlcoin',
#  'slr': 'solarcoin',
#  'bnty': 'bounty0x',
#  'yoyow': 'yoyow',
#  'vrc': 'vericoin',
#  'xel': 'elastic',
#  'jinn': 'jinn',
#  'drt': 'domraider',
#  'gup': 'guppy',
#  'nmc': 'namecoin',
#  'voise': 'voisecom',
#  'dat': 'datum',
#  'pasc': 'pascal_coin',
#  'amp': 'synereo',
#  'wrc': 'worldcore',
#  'dime': 'dimecoin',
#  'ecc': 'eccoin',
#  'hvn': 'hive',
#  'pot': 'potcoin',
#  'mnx': 'minexcoin',
#  'pepecash': 'pepe_cash',
#  'payx': 'paypex',
#  'xnn': 'xenon',
#  'tgt': 'target_coin',
#  'onion': 'deeponion',
#  'nyc': 'newyorkcoin',
#  'nlc2': 'nolimitcoin',
#  'hmq': 'humaniq',
#  'evx': 'everex',
#  'bitcny': 'bitcny',
#  'bcpt': 'blockmason',
#  'crw': 'crown',
#  'blk': 'blackcoin',
#  'msp': 'mothership',
#  'art': 'maecenas',
#  'dmd': 'diamond',
#  'grc': 'gridcoin',
#  'zsc': 'zeusshield',
#  'dovu': 'dovu',
#  'poll': 'clearpoll',
#  'pro': 'prochain',
#  'mer': 'mercury',
#  'sib': 'sibcoin',
#  'pkt': 'playkey',
#  'net': 'netcoin',
#  'colx': 'colossuscoinxt',
#  'life': 'life',
#  'xmy': 'myriad',
#  'rads': 'radium',
#  'loc': 'lockchain',
#  'dna': 'encrypgen',
#  'mda': 'moeda_loyalty_points',
#  'arn': 'aeron',
#  'linda': 'linda',
#  'snc': 'suncontract',
#  'nmr': 'numeraire',
#  'air': 'airtoken',
#  'fair': 'faircoin',
#  'blue': 'ethereum_blue',
#  'rc': 'russiacoin',
#  'ion': 'ion',
#  'rvt': 'rivetz',
#  'neu': 'neumark',
#  'exp': 'expanse',
#  'btx': 'bitcore',
#  'dbix': 'dubaicoin_dbix',
#  'pbl': 'publica',
#  'lkk': 'lykke',
#  'stx': 'stox',
#  'neos': 'neoscoin',
#  'elix': 'elixir',
#  'xwc': 'whitecoin',
#  'myst': 'mysterium',
#  'nsr': 'nushares',
#  'mue': 'monetaryunit',
#  'tix': 'blocktix',
#  'cred': 'verify',
#  'ppy': 'peerplays_ppy',
#  'bitb': 'bean_cash',
#  'phr': 'phore',
#  'omni': 'omni',
#  'golos': 'golos',
#  'flixx': 'flixxo',
#  'bot': 'bodhi',
#  'bis': 'bismuth',
#  'rby': 'rubycoin',
#  'lmc': 'lomocoin',
#  'credo': 'credo',
#  'ift': 'investfeed',
#  'divx': 'divi',
#  'dbet': 'decent_bet',
#  'hdg': 'hedge',
#  'odn': 'obsidian',
#  'bmc': 'blackmoon_crypto',
#  'alis': 'alis',
#  'oax': 'oax',
#  'cag': 'change',
#  'atb': 'atbcoin',
#  'dtb': 'databits',
#  'flo': 'florincoin',
#  'incnt': 'incent',
#  'tips': 'fedoracoin',
#  'ptoy': 'patientory',
#  'xlr': 'solaris',
#  'xrl': 'rialto',
#  'ok': 'okcash',
#  'bbr': 'boolberry',
#  'ecob': 'ecobit',
#  'bsd': 'bitsend',
#  'nxc': 'nexium',
#  'music': 'musicoin',
#  'gmt': 'mercury_protocol',
#  'kick': 'kickico',
#  'otn': 'open_trading_network',
#  'fldc': 'foldingcoin',
#  'adc': 'audiocoin',
#  'pnd': 'pandacoin_pnd',
#  'nio': 'autonio',
#  'ecn': 'e_coin',
#  'heat': 'heat_ledger',
#  'orme': 'ormeus_coin',
#  'eac': 'earthcoin',
#  'spf': 'sportyfi',
#  'mint': 'mintcoin',
#  'prg': 'paragon',
#  'plbt': 'polybius',
#  'bcap': 'bcap',
#  'posw': 'posw_coin',
#  'gcr': 'global_currency_reserve',
#  'soar': 'soarcoin',
#  'xst': 'stealthcoin',
#  'ufr': 'upfiring',
#  'wish': 'mywish',
#  'seq': 'sequence',
#  'sbd': 'steem_dollars',
#  'sprts': 'sprouts',
#  'clam': 'clams',
#  'alqo': 'alqo',
#  'gam': 'gambit',
#  'nvst': 'nvo',
#  'coval': 'circuits_of_value',
#  'time': 'chronobank',
#  'wct': 'waves_community_token',
#  'avt': 'aventus',
#  'enrg': 'energycoin',
#  'hush': 'hush',
#  'qau': 'quantum',
#  'bet': 'betacoin',
#  'swt': 'swarm_city',
#  'myb': 'mybit_token',
#  'geo': 'geocoin',
#  'pst': 'primas',
#  'cat': 'bitclave',
#  'pink': 'pinkcoin',
#  'spr': 'spreadcoin',
#  'oct': 'oraclechain',
#  'vsx': 'vsync_vsx',
#  'bcy': 'bitcrystals',
#  'zoi': 'zoin',
#  'csno': 'bitdice',
#  'bon': 'bonpay',
#  'iop': 'internet_of_people',
#  'bitusd': 'bitusd',
#  'fyp': 'flypme',
#  'esp': 'espers',
#  'ong': 'ongsocial',
#  'bq': 'bitqy',
#  'rmc': 'remicoin',
#  'bwk': 'bulwark',
#  'frst': 'firstcoin',
#  'icos': 'icos',
#  'aby': 'artbyte',
#  'ntrn': 'neutron',
#  'lux': 'luxcoin',
#  'obits': 'obits',
#  'atl': 'atlant',
#  'gbx': 'gobyte',
#  'cure': 'curecoin',
#  'brk': 'breakout',
#  'pix': 'lampix',
#  'wild': 'wild_crypto',
#  'xvc': 'vcash',
#  'xpm': 'primecoin',
#  'uno': 'unobtanium',
#  'tfl': 'trueflip',
#  'crc': 'crowdcoin',
#  'atms': 'atmos',
#  'zny': 'bitzeny',
#  'vrm': 'veriumreserve',
#  'dice': 'etheroll',
#  'leo': 'leocoin',
#  'crb': 'creditbit',
#  'b2b': 'b2bx',
#  'oxy': 'oxycoin',
#  'plu': 'pluton',
#  '1337': '1337coin',
#  'xmcc': 'monacocoin',
#  'opt': 'opus',
#  'ptc': 'pesetacoin',
#  'dope': 'dopecoin',
#  'ebst': 'eboostcoin',
#  'crave': 'crave',
#  'tx': 'transfercoin',
#  'qwark': 'qwark',
#  'sss': 'sharechain',
#  'cvcoin': 'cvcoin',
#  'chc': 'chaincoin',
#  'meme': 'memetic',
#  'xuc': 'exchange_union',
#  'itns': 'intensecoin',
#  'xaur': 'xaurum',
#  'sphr': 'sphere',
#  'sumo': 'sumokoin',
#  'bpl': 'blockpool',
#  'bela': 'belacoin',
#  'pfr': 'payfair',
#  'cann': 'cannabiscoin',
#  'alt': 'altcoin_alt',
#  'xto': 'tao',
#  'send': 'social_send',
#  'gld': 'goldcoin',
#  'ric': 'riecoin',
#  'ac': 'asiacoin',
#  'inn': 'innova',
#  'pirl': 'pirl',
#  'crea': 'creativecoin',
#  'aht': 'bowhead',
#  'zeit': 'zeitcoin',
#  'dot': 'dotcoin',
#  'snrg': 'synergy',
#  'kore': 'korecoin',
#  'btcz': 'bitcoinz',
#  'rup': 'rupee',
#  'bdl': 'bitdeal',
#  'prix': 'privatix',
#  'aur': 'auroracoin',
#  'tzc': 'trezarcoin',
#  'eltcoin': 'eltcoin',
#  'brx': 'breakout_stake',
#  'ixc': 'ixcoin',
#  'unit': 'universal_currency',
#  'tcc': 'the_champcoin',
#  'sxc': 'sexcoin',
#  'blitz': 'blitzcash',
#  'xbc': 'bitcoin_plus',
#  'rex': 'real_estate_tokens',
#  'adst': 'adshares',
#  'ufo': 'ufo_coin',
#  'carbon': 'carboncoin',
#  'drp': 'dcorp',
#  'hbt': 'hubii_network',
#  'hyp': 'hyperstake',
#  'inxt': 'internxt',
#  'astro': 'astro',
#  'hgt': 'hellogold',
#  'frd': 'farad',
#  'nobl': 'noblecoin',
#  'ett': 'encryptotel_eth',
#  'start': 'startcoin',
#  'rkc': 'royal_kingdom_coin',
#  'scl': 'social',
#  'nvc': 'novacoin',
#  '2give': '2give',
#  'ella': 'ellaism',
#  'buzz': 'buzzcoin',
#  'ind': 'indorse_token',
#  'note': 'dnotes',
#  'synx': 'syndicate',
#  'pure': 'pure',
#  'hwc': 'hollywoodcoin',
#  'vsl': 'vslice',
#  'btdx': 'bitcloud',
#  'chips': 'chips',
#  'mtnc': 'masternodecoin',
#  'apx': 'apx',
#  'zrc': 'zrcoin',
#  'edr': 'e_dinar_coin',
#  'mag': 'magnet',
#  'qvt': 'qvolta',
#  'toa': 'toacoin',
#  'proc': 'procurrency',
#  'qrk': 'quark',
#  'real': 'real',
#  'mbrs': 'embers',
#  'usnbt': 'nubits',
#  'trust': 'trustplus',
#  'vtr': 'vtorrent',
#  'excl': 'exclusivecoin',
#  'tks': 'tokes',
#  'pzm': 'prizm',
#  'pop': 'popularcoin',
#  'bbt': 'bitboost',
#  'erc': 'europecoin',
#  'ero': 'eroscoin',
#  'dyn': 'dynamic',
#  'pdc': 'project_decorum',
#  'cmpco': 'campuscoin',
#  'xmg': 'magi',
#  'dft': 'draftcoin',
#  'stu': 'student_coin',
#  'dgpt': 'digipulse',
#  'egc': 'evergreencoin',
#  'vivo': 'vivo',
#  'linx': 'linx',
#  'pkb': 'parkbyte',
#  'xgox': 'xgox',
#  'nka': 'incakoin',
#  'anc': 'anoncoin',
#  'wdc': 'worldcoin',
#  'moin': 'moin',
#  'eqt': 'equitrader',
#  'put': 'putincoin',
#  'rustbits': 'rustbits',
#  'zeph': 'zephyr',
#  'for': 'force',
#  'rain': 'condensate',
#  'unify': 'unify',
#  'huc': 'huntercoin',
#  'trc': 'terracoin',
#  'ctx': 'cartaxi_token',
#  'rec': 'regalcoin',
#  'hold': 'interstellar_holdings',
#  'swift': 'bitswift',
#  'mxt': 'martexcoin',
#  'good': 'goodomy',
#  'krb': 'karbowanec',
#  'flik': 'flik',
#  'bun': 'bunnycoin',
#  'epy': 'emphy',
#  'hat': 'hawala_today',
#  'xft': 'footy_cash',
#  'gre': 'greencoin',
#  'efl': 'e_gulden',
#  'xcpo': 'copico',
#  'ebtc': 'ebtcnew',
#  'gim': 'gimli',
#  'dnr': 'denarius_dnr',
#  'etbs': 'ethbits',
#  'blu': 'bluecoin',
#  'cft': 'cryptoforecast',
#  'yoc': 'yocoin',
#  'ping': 'cryptoping',
#  'arc': 'arcade_token',
#  'v': 'version',
#  'fjc': 'fujicoin',
#  'rns': 'renos',
#  'adl': 'adelphoi',
#  'bash': 'luckchain',
#  'ldoge': 'litedoge',
#  'stak': 'straks',
#  'dp': 'digitalprice',
#  'mcap': 'mcap',
#  'dcy': 'dinastycoin',
#  'gcc': 'guccionecoin',
#  'xcn': 'cryptonite',
#  'bro': 'bitradio',
#  'insn': 'insanecoin_insn',
#  'erc20': 'erc20',
#  'xlc': 'leviarcoin',
#  'ndc': 'neverdie',
#  'sta': 'starta',
#  'byc': 'bytecent',
#  'pbt': 'primalbase',
#  'fst': 'fastcoin',
#  'ebet': 'ethbet',
#  'flt': 'fluttercoin',
#  'dar': 'darcrus',
#  'cbx': 'cryptogenic_bullion',
#  'ele': 'elementrem',
#  'zer': 'zero',
#  'itt': 'intelligent_trading_tech',
#  'fyn': 'fundyourselfnow',
#  'lnk': 'link_platform',
#  'kln': 'kolion',
#  'uis': 'unitus',
#  'iflt': 'inflationcoin',
#  'efyt': 'ergo',
#  'mrt': 'miners_reward_token',
#  'kurt': 'kurrent',
#  'ocl': 'oceanlab',
#  'unb': 'unbreakablecoin',
#  'lgd': 'legends_room',
#  'crm': 'cream',
#  'mec': 'megacoin',
#  'q2c': 'qubitcoin',
#  'adz': 'adzcoin',
#  'cdn': 'canada_ecoin',
#  'ecash': 'ethereumcash',
#  'hal': 'halcyon',
#  'zeni': 'zennies',
#  'ttc': 'tittiecoin',
#  'icoo': 'ico_openledger',
#  'mzc': 'mazacoin',
#  'bta': 'bata',
#  'pipl': 'piplcoin',
#  'visio': 'visio',
#  'acc': 'adcoin',
#  'otx': 'octanox',
#  'ats': 'authorship',
#  'grwi': 'growers_international',
#  'xbl': 'billionaire_token',
#  'mac': 'machinecoin',
#  'xcxt': 'coinonatx',
#  'dai': 'dai',
#  'zet': 'zetacoin',
#  'infx': 'influxcoin',
#  'daxx': 'daxxcoin',
#  'dsr': 'desire',
#  'orb': 'orbitcoin',
#  'cco': 'ccore',
#  'btcs': 'bitcoin_silver',
#  'tes': 'teslacoin',
#  'crx': 'chronos',
#  'gun': 'guncoin',
#  'skin': 'skincoin',
#  'strc': 'starcredits',
#  'piggy': 'piggycoin',
#  'riya': 'etheriya',
#  'netko': 'netko',
#  'xpd': 'petrodollar',
#  'htc': 'hitcoin',
#  'dgc': 'digitalcoin',
#  'fuck': 'fucktoken',
#  'smc': 'smartcoin',
#  'btb': 'bitbar',
#  'cct': 'crystal_clear',
#  'fcn': 'fantomcoin',
#  'bbp': 'biblepay',
#  'trct': 'tracto',
#  'saga': 'sagacoin',
#  'pak': 'pakcoin',
#  'cnt': 'centurion',
#  'dfs': 'dfscoin',
#  'xios': 'xios',
#  'kek': 'kekcoin',
#  'corg': 'corgicoin',
#  'nuko': 'nekonium',
#  'cpc': 'capricoin',
#  'smly': 'smileycoin',
#  'bigup': 'bigup',
#  'drxne': 'droxne',
#  'au': 'aurumcoin',
#  'sgr': 'sugar_exchange',
#  'bpc': 'bitpark_coin',
#  'cfd': 'confido',
#  'cj': 'cryptojacks',
#  'kobo': 'kobocoin',
#  'i0c': 'i0coin',
#  'troll': 'trollcoin',
#  'mne': 'minereum',
#  'tkr': 'trackr',
#  'utc': 'ultracoin',
#  'dem': 'deutsche_emark',
#  'mcrn': 'macron',
#  'zcg': 'zcash_gold',
#  'nyan': 'nyancoin',
#  'whl': 'whalecoin',
#  'fc2': 'fuelcoin',
#  'ams': 'amsterdamcoin',
#  'brit': 'britcoin',
#  'max': 'maxcoin',
#  'lana': 'lanacoin',
#  'trump': 'trumpcoin',
#  'score': 'scorecoin',
#  'blas': 'blakestar',
#  'wgo': 'wavesgo',
#  'bits': 'bitstar',
#  'tri': 'triangles',
#  'pasl': 'pascal_lite',
#  'gaia': 'gaia',
#  'rbt': 'rimbit',
#  'mbi': 'monster_byte',
#  '42': '42_coin',
#  'klc': 'kilocoin',
#  'atom': 'atomic_coin',
#  'monk': 'monkey_project',
#  'hbn': 'hobonickels',
#  'hpc': 'happycoin',
#  'blockpay': 'blockpay',
#  'iti': 'iticoin',
#  'xjo': 'joulecoin',
#  'hodl': 'hodlcoin',
#  'ent': 'entcash',
#  'gb': 'goldblocks',
#  'ccn': 'cannacoin',
#  'trk': 'truckcoin',
#  'altcom': 'altcommunity_coin',
#  'pxc': 'phoenixcoin',
#  'coal': 'bitcoal',
#  'pos': 'postoken',
#  '888': 'octocoin',
#  '8bit': '8bit',
#  'xptx': 'platinumbar',
#  'pr': 'prototanium',
#  'kush': 'kushcoin',
#  'etg': 'ethereum_gold',
#  'sigt': 'signatum',
#  'ammo': 'ammo_rewards',
#  'opal': 'opal',
#  'super': 'supercoin',
#  'c2': 'coin2_1',
#  'ytn': 'yenten',
#  'trdt': 'trident',
#  'btcred': 'bitcoin_red',
#  'vlt': 'veltor',
#  'red': 'redcoin',
#  'vidz': 'purevidz',
#  'xhi': 'hicoin',
#  'ntwk': 'network_token',
#  'abj': 'abjcoin',
#  'cv2': 'colossuscoin_v2',
#  'mnc': 'mincoin',
#  'onx': 'onix',
#  'wtt': 'giga_watt_token',
#  'mars': 'marscoin',
#  'tit': 'titcoin',
#  'dix': 'dix_asset',
#  'xct': 'c_bit',
#  'lbtc': 'lightning_bitcoin',
#  'slg': 'sterlingcoin',
#  'sdrn': 'senderon',
#  'fnc': 'fincoin',
#  'xpy': 'paycoin2',
#  'bucks': 'swagbucks',
#  'dsh': 'dashcoin',
#  'ltb': 'litebar',
#  'ari': 'aricoin',
#  'mnm': 'mineum',
#  'pcoin': 'pioneer_coin',
#  'jet': 'jetcoin',
#  'unic': 'unicoin',
#  'eot': 'eot_token',
#  'evil': 'evil_coin',
#  '4chn': 'chancoin',
#  'nto': 'fujinto',
#  'roc': 'rasputin_online_coin',
#  'xgr': 'goldreserve',
#  'cno': 'coin',
#  'lcp': 'litecoin_plus',
#  'ddf': 'digital_developers_fund',
#  'hxx': 'hexx',
#  'stars': 'starcash_network',
#  'tgc': 'tigercoin',
#  'el': 'elcoin_el',
#  'uny': 'unity_ingot',
#  'xra': 'ratecoin',
#  'tse': 'tattoocoin',
#  'mojo': 'mojocoin',
#  'cube': 'digicube',
#  'grim': 'grimcoin',
#  'duo': 'parallelcoin',
#  'ccrb': 'cryptocarbon',
#  'bcf': 'bitcoinfast',
#  'ebch': 'ebitcoin_cash',
#  'bxt': 'bittokens',
#  'gap': 'gapcoin',
#  'pxi': 'prime_xi',
#  'post': 'postcoin',
#  'boli': 'bolivarcoin',
#  'soon': 'sooncoin',
#  'space': 'spacecoin',
#  'swing': 'swing',
#  'kayi': 'kayicoin',
#  'tag': 'tagcoin',
#  'bern': 'berncash',
#  'blc': 'blakecoin',
#  'glt': 'globaltoken',
#  'aib': 'advanced_internet_blocks',
#  'dalc': 'dalecoin',
#  'emd': 'emerald',
#  'hero': 'sovereign_hero',
#  'chess': 'chesscoin',
#  'euc': 'eurocoin',
#  'egas': 'ethgas',
#  'cnnc': 'cannation',
#  'zzc': 'zozocoin',
#  'uni': 'universe',
#  'ked': 'darsek',
#  'brat': 'brat',
#  'bitbtc': 'bitbtc',
#  'bsty': 'globalboost_y',
#  'units': 'gameunits',
#  'moto': 'motocoin',
#  'stv': 'sativacoin',
#  'honey': 'honey',
#  'rlt': 'roulettetoken',
#  'qtl': 'quatloo',
#  'arco': 'aquariuscoin',
#  'ree': 'reecoin',
#  '611': 'sixeleven',
#  'vot': 'votecoin',
#  'mar': 'marijuanacoin',
#  'phs': 'philosopher_stones',
#  'btpl': 'bitcoin_planet',
#  'grt': 'grantcoin',
#  'btwty': 'bit20',
#  'arg': 'argentum',
#  'shdw': 'shadow_token',
#  'icob': 'icobid',
#  'ieth': 'iethereum',
#  'ethd': 'ethereum_dark',
#  'hnc': 'huncoin',
#  'xre': 'revolvercoin',
#  'tek': 'tekcoin',
#  'mtlmc3': 'metal_music_coin',
#  'zur': 'zurcoin',
#  'src': 'securecoin',
#  'eagle': 'eaglecoin',
#  'ery': 'eryllium',
#  'bln': 'bolenum',
#  'xco': 'x_coin',
#  'mad': 'satoshimadness',
#  'qcn': 'quazarcoin',
#  'bumba': 'bumbacoin',
#  'jin': 'jin_coin',
#  'ims': 'independent_money_system',
#  'nro': 'neuro',
#  'bas': 'bitasean',
#  'gpu': 'gpu_coin',
#  'mao': 'mao_zedong',
#  'con': 'paycon',
#  'rbies': 'rubies',
#  'krone': 'kronecoin',
#  '$$$': 'money',
#  'xvp': 'virtacoinplus',
#  'sfc': 'solarflarecoin',
#  'ereal': 'ereal',
#  'func': 'funcoin',
#  'rpc': 'ronpaulcoin',
#  'evo': 'evotion',
#  'cpn': 'compucoin',
#  'cxt': 'coinonat',
#  'aerm': 'aerium',
#  'neva': 'nevacoin',
#  'cach': 'cachecoin',
#  'vec2': 'vector',
#  'xcre': 'creatio',
#  'vuc': 'virta_unique_coin',
#  'bitsilver': 'bitsilver',
#  'spex': 'sproutsextreme',
#  'newb': 'newbium',
#  'acoin': 'acoin',
#  'bip': 'bipcoin',
#  'gp': 'goldpieces',
#  'hmp': 'hempcoin_hmp',
#  'gpl': 'gold_pressed_latinum',
#  'eco': 'ecocoin',
#  'song': 'songcoin',
#  'drs': 'digital_rupees',
#  'mst': 'mustangcoin',
#  'yac': 'yacoin',
#  'rupx': 'rupaya_old',
#  'soil': 'soilcoin',
#  'flax': 'flaxscript',
#  'ice': 'idice',
#  'zmc': 'zetamicron',
#  'bnx': 'bnrtxcoin',
#  'may': 'theresa_may_coin',
#  'xbts': 'beatcoin',
#  'imx': 'impact',
#  'spt': 'spots',
#  'boat': 'doubloon',
#  'gtc': 'game',
#  'fuzz': 'fuzzballs',
#  'luna': 'luna_coin',
#  'bitgold': 'bitgold',
#  'benji': 'benjirolls',
#  'worm': 'healthywormcoin',
#  'taj': 'tajcoin',
#  'usde': 'usde',
#  'lea': 'leacoin',
#  'all': 'allion',
#  'token': 'swaptoken',
#  'vprc': 'vaperscoin',
#  'exn': 'exchangen',
#  'asafe2': 'allsafe',
#  'roofs': 'roofs',
#  'milo': 'milocoin',
#  'tor': 'torcoin_tor',
#  'cto': 'crypto',
#  'bstar': 'blackstar',
#  'cf': 'californium',
#  'ltcu': 'litecoin_ultra',
#  'rbx': 'ripto_bux',
#  'placo': 'playercoin',
#  'qbc': 'quebecoin',
#  'mscn': 'master_swiscoin',
#  'dbtc': 'debitcoin',
#  '300': '300_token',
#  'g3n': 'genstake',
#  'icon': 'iconic',
#  'women': 'women',
#  'pie': 'piecoin',
#  'wbb': 'wild_beast_block',
#  'slevin': 'slevin',
#  'atx': 'artex_coin',
#  'vltc': 'vault_coin',
#  'drm': 'dreamcoin',
#  'uet': 'useless_ethereum_token',
#  'prx': 'printerium',
#  'biteur': 'biteur',
#  'crdnc': 'credence_coin',
#  'geert': 'geertcoin',
#  'urc': 'unrealcoin',
#  'acp': 'anarchistsprime',
#  'off': 'cthulhu_offerings',
#  'ctic3': 'coimatic_3',
#  'prc': 'prcoin',
#  'bsc': 'bowscoin',
#  'tycho': 'tychocoin',
#  'dollar': 'dollar_online',
#  'ride': 'ride_my_car',
#  'argus': 'argus',
#  'xcs': 'cybcsec',
#  'vrs': 'veros',
#  'ibank': 'ibank',
#  'rsgp': 'rsgpcoin',
#  'ego': 'ego',
#  'crtm': 'corethum',
#  'scs': 'speedcash',
#  'socc': 'socialcoin_socc',
#  'b3': 'b3coin',
#  'brain': 'braincoin',
#  'jobs': 'jobscoin',
#  'zne': 'zonecoin',
#  'volt': 'bitvolt',
#  'lvps': 'levoplus',
#  'fxe': 'futurexe',
#  'creva': 'crevacoin',
#  'els': 'elysium',
#  'aglc': 'agrolifecoin',
#  'ctic2': 'coimatic_2',
#  'mgm': 'magnum',
#  'p7c': 'p7coin',
#  'xrc': 'rawcoin2',
#  'gsr': 'geysercoin',
#  'tstr': 'tristar_coin',
#  'nanox': 'project_x',
#  'conx': 'concoin',
#  'slfi': 'selfiecoin',
#  'xng': 'enigma',
#  'hmc': 'harmonycoin_hmc',
#  'dgcs': 'digital_credits',
#  'ebt': 'ebittree_coin',
#  'abn': 'abncoin',
#  'dmb': 'digital_money_bits',
#  'calc': 'caliphcoin',
#  'apw': 'applecoin_apw',
#  'unity': 'supernet_unity',
#  'emv': 'ethereum_movie_venture',
#  'pho': 'photon',
#  'gcn': 'gcoin',
#  'vta': 'virtacoin',
#  'pgl': 'prospectors_gold',
#  '808': '808coin',
#  'funk': 'the_cypherfunks',
#  'inpay': 'inpay',
#  'jns': 'janus',
#  'yash': 'yashcoin',
#  'fimk': 'fimkrypto',
#  'crypt': 'cryptcoin',
#  'sift': 'smart_investment_fund_token',
#  'log': 'woodcoin',
#  'shorty': 'shorty',
#  'lot': 'lottocoin',
#  'sdc': 'shadowcash',
#  'metal': 'metalcoin',
#  'b@': 'bankcoin',
#  'itz': 'interzone',
#  'sts': 'stress',
#  'amber': 'ambercoin',
#  'mrja': 'ganjacoin',
#  'wyv': 'wyvern',
#  'btsr': 'btsr',
#  'val': 'valorbit',
#  'bria': 'briacoin',
#  'glc': 'globalcoin',
#  'way': 'wayguide',
#  'btcr': 'bitcurrency',
#  'blz': 'blazecoin',
#  'usc': 'ultimate_secure_cash',
#  'j': 'joincoin',
#  'px': 'px',
#  'mut': 'mutual_coin',
#  'scrt': 'secretcoin',
#  ...}

# %%
# Replace all symbols unigram_sentences with their more common name, using crypto_dict
unigram_sentences_replaced = []
for i, sentence in enumerate(unigram_sentences):
    for j, word in enumerate(sentence):
        key = word
        if key in crypto_dict:
            sentence[j] = crypto_dict[key]
    unigram_sentences_replaced.append(sentence)

# %%
unigram_sentences = unigram_sentences_replaced

# %%
sentences_nostop = []
STOP_WORDS.add("rt")
for i, sentence in enumerate(unigram_sentences):
    sentence_nostop = [token for token in sentence if token not in STOP_WORDS]
    sentences_nostop.append(sentence_nostop)

# %%
unigram_sentences = sentences_nostop

# %%
for sentence in it.islice(unigram_sentences, 230, 240):
    print(sentence)
# Out:
# ['join', '-PRON-', 'ico']
# ['chainlink', '-PRON-', 'know', '😉']
# ['particl', 'ecocryptomin', 'world']
# ['invest', 'investment', 'innovate', 'innovation', 'mining', 'miningfarm', 'crypto', 'profit', 'bitcoin', 'ethereum', 'cryptocurrency']
# ['st']
# ['james', 'place', 'condos', 'columbia', 'heights', 'accept', 'bitcoin', 'payment', 'washington', 'business', 'journal']
# []
# ['-PRON-', 'mywish', 'man', 'putincoin', 'confidence', 'woman', '-PRON-', 'bitcoin']
# ['direct', 'correlation', 'growth', 'number', 'successful', 'reliable', 'project', 'arrival', 'new', 'investor', 'market', 'interest', 'increase', 'significantly']
# ['rr', 'revizorcoin', 'cryptocurrency', 'ico', 'blockchain']

# %%
bigram_sentences_filepath = '../data/bigram_sentences.txt'

# %%
# Trains the detector
bigram_model = Phrases(unigram_sentences)
# Out:
# E:\anaconda\lib\site-packages\gensim\models\phrases.py:317: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if all(parameter in getargspec(scoring)[0] for parameter in scoring_parameters):
# E:\anaconda\lib\site-packages\gensim\models\phrases.py:317: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if all(parameter in getargspec(scoring)[0] for parameter in scoring_parameters):
# E:\anaconda\lib\site-packages\gensim\models\phrases.py:317: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if all(parameter in getargspec(scoring)[0] for parameter in scoring_parameters):
# E:\anaconda\lib\site-packages\gensim\models\phrases.py:317: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if all(parameter in getargspec(scoring)[0] for parameter in scoring_parameters):
# E:\anaconda\lib\site-packages\gensim\models\phrases.py:317: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if all(parameter in getargspec(scoring)[0] for parameter in scoring_parameters):
# E:\anaconda\lib\site-packages\gensim\models\phrases.py:317: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if all(parameter in getargspec(scoring)[0] for parameter in scoring_parameters):

# %%
with open(bigram_sentences_filepath, 'w', encoding='utf_8') as f:
    for unigram_sentence in unigram_sentences:
        bigram_sentence = bigram_model[unigram_sentence]
        for word in bigram_sentence:
            f.write(word)
            f.write(" ")
        f.write("\n")
# Out:
# E:\anaconda\lib\site-packages\gensim\models\phrases.py:486: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")

# %%
bigram_sentences = LineSentence(bigram_sentences_filepath)

# %%
for sentence in it.islice(bigram_sentences, 800, 850):
    print(sentence)
# Out:
# ['ethereum', 'cloudmin', 'bitcoininvest']
# ['-PRON-', 'bitcoin', 'early_god', 'bless', '-PRON-', 'small_fortune']
# ['-PRON-', 'want_help']
# ['-PRON-', 'away_20', 'bitcoin', '20_random', 'people_retweet', 'jan_30th']
# ['-PRON-', 'hope_help', '-PRON-', '-PRON-', 'help', '-PRON-']
# ['$', '5,000', 'cryptocurrency', 'giveaway_nebulas_token', 'daily_ben', 'yu']
# ['alphabitcoinfund', 'news', '-PRON-']
# ['find', '-PRON-', 'visit']
# ['sudangc', 'sudan', 'gold', 'coin', 'moneycoin', 'blockchain', 'ethereum', 'ethereumclassic', 'bitcoin', 'ico', 'swaptoken', 'investment', 'cryptocurrency']
# ['news', 'yahoo', 'nasdaq', 'finance', 'business']
# ['abcnews']
# ['famous']
# ['$', '5', 'homeless', 'person', '-PRON-', 'buy', 'food', 'instead', 'invest', '-PRON-', 'bitcoin', 'smh']
# ['cindicator', 'cindicator', '-PRON-', '150']
# ['tech', 'datum', 'poly_ai', 'ml', 'bitcoin']
# ['ethereum']
# ['content_and_ad_network', '-PRON-', 'invite_allion', '-PRON-', 'girlfriend_come', 'vegas_force', 'cryptoball']
# ['-PRON-', 'allion', 'bitcoin']
# ['miss', 'uor', 'ico']
# ['highrewardcoin_hrc', 'bitcoin', 'ico', 'cryptocurrency']
# ['速報_韓国最大手取引所のbithumbとkorbitは国内総資産額', '1位の巨大銀行_国民銀行', 'から入出金を停止させられるも_代わりに国内', '2位となる_新韓銀行', 'が入出金を提供する模様']
# ['政治的対立とみられる_ビットコイン', '仮想通貨', 'bitcoin', '$', 'bitcoin', 'ブロックチェーン_イーサリアム', 'リップル_韓国']
# ['lambo', 'force', 'sale_hotel', 'parking_lottocoin']
# ['crypto']
# ['goodomy_luck', 'buddy']
# ['475_k', '$', 'ripple']
# ['lmao']
# ['btcmiami_tnabc', 'bitcoin', 'xrpthestandard']
# ['find', 'viceindustrytoken', 'monetize', 'attention', 'economy', 'read', '-PRON-', 'whitepaper', 'blockchain']
# ['cryptocurrency', 'pornography']
# ['check', '-PRON-', 'late', 'interview', 'techbullion']
# ['tapcoin', 'ethereum', 'cryptocurrency', 'blockchaingam']
# ['alphabitcoinfund', 'news', '-PRON-']
# ['find', '-PRON-', 'visit']
# ['sudangc', 'sudan', 'gold', 'coin', 'moneycoin', 'blockchain', 'ethereum', 'ethereumclassic', 'bitcoin', 'ico', 'swaptoken', 'investment', 'cryptocurrency']
# ['news', 'yahoo', 'nasdaq', 'finance', 'business']
# ['abcnews']
# ['famous']
# ['roboforex', 'introduces', 'bitcoin', 'account', 'base', 'currency']
# ['bitcoin', 'isn', 't', 'funfair', 'gamecredits']
# ['s', '-PRON-', 'content_and_ad_network', 't', 'buy', 'high_gain', 'end', 'graphic', 'card', 'goodomy', 'buy']
# ['new_research']
# ['laundering_illicit', 'funds_1', 'bitcoin', 'transactions', 'bitcoin']
# ['-PRON-', 'join', 'bitcoin', 'unicorn', '-PRON-', 'follow', '-PRON-']
# ['wildly', 'inaccurate', 'people_buy', 'bitcoin', 'crypto', 'intent', 'spend', '-PRON-']
# ['-PRON-', 'wonder']
# ['quel', 'économiste', 'de', 'renom', 'se', 'warren', 'buffett', 'tort', 'suretly', 'bitcoin', 'comment', 'obtenir', 'compte', 'bitcoin']
# ['bithumb_korbit', 'large', 'cryptocurrency', 'exchange_south', 'korea_disable', 'kookmin_bank', 'deposit_withdrawal']
# ['instead', '-PRON-', 'allow_shinhan', 'bank_second', 'large_bank', 'deposit_withdrawal']
# ['mean_shinhan', 'bank_process', 'payment', 'force_trader']

# %%
dictionary_filepath = '../data/dictionary.dict'

# %%
dictionary = Dictionary(bigram_sentences)

# %%
dictionary.filter_extremes(no_below=5, no_above=0.5)
dictionary.compactify()
dictionary.save(dictionary_filepath)

# %%
def bow_generator(filepath):    
    for tweet in LineSentence(filepath):
        yield dictionary.doc2bow(tweet)

# %%
bow_filepath = "../data/bow.mm"

# %%
MmCorpus.serialize(bow_filepath, bow_generator(bigram_sentences_filepath))
bow_corpus = MmCorpus(bow_filepath)

# %%
bow_corpus[43]
# Out:
# [(6, 1.0), (14, 1.0), (30, 3.0), (40, 2.0), (61, 1.0)]
